# %% [markdown]
# In this notebook, I will leverage the [Sport Reference](https://www.sports-reference.com) network, a robust collection of websites dedicated to providing statistical data, analysis, and historical insights across a range of sports. Specifically, I will focus on retrieving football data from their platform, ensuring compliance with their rate limiting policy as outlined on their [bot-traffic page](https://www.sports-reference.com/bot-traffic.html). This implementation will involve careful management of request frequency to respect their guidelines while extracting valuable statistical information for analysis.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from typing import Union, List
import time
import logging

# %%
# Clear global logging handlers
logging.getLogger().handlers.clear()
# Configure a logger for the main script
main_logger = logging.getLogger(__name__)
main_logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
formatter = logging.Formatter('[%(levelname)s] (%(name)s) : %(message)s')
handler.setFormatter(formatter)
main_logger.addHandler(handler)

# Create a class for scraping data
class Scraper:
    instance_created = False

    def __init__(self, force_new_instance=False):
        if Scraper.instance_created and not force_new_instance:
            raise Exception("An instance of Scraper has already been created.")
        Scraper.instance_created = True

        self.start_time = time.time()  # Start time of the class instance
        self.call_count = 0  # Counter for the number of URL calls
        self.max_calls_per_minute = 9  # Limit of calls allowed per minute
        self.last_reset_time = time.time()  # Last time the call counter was reset
        self.configure_logging()  # Configure logging
        self.logger.info("Scraper initialized.")


    def configure_logging(self):
        """Configures the logger for the Scraper class."""
        self.logger = logging.getLogger("Scrape")
        self.logger.setLevel(logging.INFO)
        handler = logging.StreamHandler()
        formatter = logging.Formatter('[%(levelname)s] (%(name)s.%(funcName)s) : %(message)s')
        handler.setFormatter(formatter)
        # Add the handler to the logger
        if not self.logger.hasHandlers():  # Check if there are already handlers to avoid duplication
            self.logger.addHandler(handler)


    def _reset_call_count_if_needed(self):
        """Resets the call count if a minute has passed since the last reset."""
        current_time = time.time()
        if current_time - self.last_reset_time > 58:
            self.call_count = 0
            self.last_reset_time = current_time
            self.logger.info("Resetting call count.")


    def fetch_html_content(self, url: str) -> Union[bytes, None]:
        """
        Fetch HTML content from a given URL with retry mechanism for error 429.

        Parameters:
        - url (str): The URL to request.

        Returns:
        - bytes (raw HTML content) if the request is successful.
        - None if the request fails.
        """
        self._reset_call_count_if_needed()

        # Wait if the maximum calls per minute limit is reached
        if self.call_count >= self.max_calls_per_minute:
            wait_time = 62 - (time.time() - self.last_reset_time)
            self.logger.warning(f"Maximum call limit reached. Waiting for {wait_time:.2f} seconds.")
            time.sleep(wait_time)  # Wait until the limit resets
            self.call_count = 0  # Reset after waiting
            self.last_reset_time = time.time()
        try:
            response = requests.get(url)
            response.raise_for_status()  # Raises an error if the request fails
            self.call_count += 1  # Increment call count
            self.logger.info(f"Fetching HTML content from {url}. Call count: {self.call_count}.")
            return response.content

        except requests.exceptions.HTTPError as e:
            if response.status_code == 429:  # Too Many Requests error
                raise SystemExit(f"*** Request failed with 429 error -> session in jail for up to a day. ***")
            else:
                raise SystemExit(f"*** Request failed: {e} ***")


    def get_team_urls(self, response_content: bytes) -> List[str]:
        """
        Retrieves the URLs for team pages of a specific Premier League season from 'https://fbref.com/en/comps'.

        Parameters:
        - response_content (bytes): The HTML content of the season standings page.

        Returns:
        - list of str: Full URLs linking to each team's squad page for the season.
        """
        soup = BeautifulSoup(response_content, 'html.parser')
        standings_table = soup.find('table', class_='stats_table')
        if not standings_table:
            self.logger.warning("Standings table not found on the page.")
            return []

        # Extract links related to teams
        team_links = [
            f"https://fbref.com{a.get('href')}"
            for a in standings_table.find_all('a', href=True)
            if '/squads/' in a.get('href', '')
        ]
        return team_links


    def extract_table_from_html(self, html_content: bytes, table_match: str) -> pd.DataFrame:
        """
        Extracts a table from HTML content based on a specific match string.

        Parameters:
        - html_content (bytes): HTML content.
        - table_match (str): The string to match the desired table.

        Returns:
        - pd.DataFrame: DataFrame containing the table data if found, or an empty DataFrame.
        """
        try:
            table = pd.read_html(html_content, match=table_match)[0]
            self.logger.info(f"Found table '{table_match}'.")
            return table
        except ValueError:
            self.logger.warning(f"Table matching '{table_match}' not found.")
            return pd.DataFrame()  # Return an empty DataFrame if no table matches


    def get_shooting_data(self, response_content: bytes) -> pd.DataFrame:
        """
        Extracts shooting data for a specific team during a season from the provided HTML content.

        Parameters:
        - response_content (bytes): The HTML content of the team’s page containing team data.

        Returns:
        - pd.DataFrame: DataFrame containing the shooting data of a team in a specific season if successful, or an empty DataFrame if there was an error.
        """
        soup = BeautifulSoup(response_content, 'html.parser')
        # Extract shooting link related to the team
        shooting_links = [
            f"https://fbref.com{a.get('href')}"
            for a in soup.find_all('a', href=True)
            if 'all_comps/shooting/' in a.get('href', '')
        ]

        if not shooting_links:
            self.logger.warning("Shooting data link not found.")
            return pd.DataFrame()

        # Fetch and extract shooting data
        shooting_html = self.fetch_html_content(shooting_links[0])
        if shooting_html:
            return self.extract_table_from_html(shooting_html, "Shooting")
        else:
            return pd.DataFrame()

# %%
scraper = Scraper()

standings_url = 'https://fbref.com/en/comps/9/Premier-League-Stats'
standings_html = scraper.fetch_html_content(standings_url)
team_urls = scraper.get_team_urls(standings_html)

team_url = team_urls[0]
team_html = scraper.fetch_html_content(team_url)
match_data = scraper.extract_table_from_html(team_html, "Scores & Fixtures")
shooting_data = scraper.get_shooting_data(team_html)

print("\n'match_data' shape:", match_data.shape)
display(match_data.head(3))
print("\n'shooting_data' shape:", shooting_data.shape)
display(shooting_data.head(3))
# Out:
# [INFO] (Scrape.__init__) : Scraper initialized.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/comps/9/Premier-League-Stats. Call count: 1.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# 'match_data' shape: (49, 20)
#          Date   Time                 Comp                Round  Day Venue  \
# 0  2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1  2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2  2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
#
#   Result     GF     GA        Opponent   xG  xGA  Poss  Attendance  \
# 0      D  1 (7)  1 (6)  Manchester Utd  NaN  NaN  56.0     78146.0
# 1      W      2      0         Chelsea  0.8  1.0  52.0     39818.0
# 2      W      4      1    Ipswich Town  3.3  0.3  75.0     53147.0
#
#            Captain Formation Opp Formation         Referee  Match Report  \
# 0       Rúben Dias     4-3-3       4-2-3-1  Jarred Gillett  Match Report
# 1  Kevin De Bruyne   3-2-4-1       4-2-3-1  Anthony Taylor  Match Report
# 2  Kevin De Bruyne   3-2-4-1         5-4-1  Samuel Allison  Match Report
#
#                                                Notes
# 0  Manchester City won on penalty kicks following...
# 1                                                NaN
# 2                                                NaN
# 'shooting_data' shape: (15, 26)
#   For Manchester City                                                        \
#                  Date   Time                 Comp                Round  Day
# 0          2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat
# 1          2024-08-18  16:30       Premier League          Matchweek 1  Sun
# 2          2024-08-24  15:00       Premier League          Matchweek 2  Sat
#
#                                              Standard                      \
#   Venue Result     GF     GA        Opponent      Gls  Sh SoT  SoT%  G/Sh
# 0  Home      D  1 (7)  1 (6)  Manchester Utd        1   9   1  11.1  0.11
# 1  Away      W      2      0         Chelsea        2  11   5  45.5  0.18
# 2  Home      W      4      1    Ipswich Town        4  13   4  30.8  0.23
#
#                             Expected                            \
#   G/SoT  Dist   FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG
# 0  1.00   NaN  NaN  0     0      NaN  NaN     NaN  NaN     NaN
# 1  0.40  19.1  0.0  0     0      0.8  0.8    0.07  1.2     1.2
# 2  0.75  17.8  1.0  1     1      3.3  2.6    0.20  0.7     0.4
#
#   Unnamed: 25_level_0
#          Match Report
# 0        Match Report
# 1        Match Report
# 2        Match Report

# %% [markdown]
# We can observe two things from this dataset:
#
#
# 1.   `shooting_data` has multiple levels of column names, and the outer level can be removed.
# 2.   The shapes differ: `shooting_data` doesn't include all matches.

# %%
# Remove the outer level
shooting_data.columns = shooting_data.columns.droplevel()

shooting_data.head()
# Out:
#          Date   Time                 Comp                Round  Day Venue  \
# 0  2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1  2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2  2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3  2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
# 4  2024-09-14  15:00       Premier League          Matchweek 4  Sat  Home
#
#   Result     GF     GA        Opponent  Gls  Sh  SoT  SoT%  G/Sh  G/SoT  Dist  \
# 0      D  1 (7)  1 (6)  Manchester Utd    1   9    1  11.1  0.11   1.00   NaN
# 1      W      2      0         Chelsea    2  11    5  45.5  0.18   0.40  19.1
# 2      W      4      1    Ipswich Town    4  13    4  30.8  0.23   0.75  17.8
# 3      W      3      1        West Ham    3  23    8  34.8  0.13   0.38  15.0
# 4      W      2      1       Brentford    2  18    7  38.9  0.11   0.29  17.2
#
#     FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  Match Report
# 0  NaN   0      0  NaN   NaN      NaN   NaN      NaN  Match Report
# 1  0.0   0      0  0.8   0.8     0.07   1.2      1.2  Match Report
# 2  1.0   1      1  3.3   2.6     0.20   0.7      0.4  Match Report
# 3  1.0   0      0  3.0   3.0     0.13   0.0      0.0  Match Report
# 4  0.0   0      0  2.1   2.1     0.12  -0.1     -0.1  Match Report

# %%
# Combine 'match_data' with `shooting_data` mantaining only specific stats
team_data = match_data.merge(shooting_data[['Date', 'Sh', 'SoT', 'SoT%', 'G/Sh', 'G/SoT', 'Dist', 'FK', 'PK',
                                          'PKatt', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG']], on='Date')

print("'team_data' shape:", team_data.shape)

team_data.head()
# Out:
# 'team_data' shape: (14, 33)
#          Date   Time                 Comp                Round  Day Venue  \
# 0  2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1  2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2  2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3  2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
# 4  2024-09-14  15:00       Premier League          Matchweek 4  Sat  Home
#
#   Result     GF     GA        Opponent   xG  xGA  Poss  Attendance  \
# 0      D  1 (7)  1 (6)  Manchester Utd  NaN  NaN  56.0     78146.0
# 1      W      2      0         Chelsea  0.8  1.0  52.0     39818.0
# 2      W      4      1    Ipswich Town  3.3  0.3  75.0     53147.0
# 3      W      3      1        West Ham  3.0  0.7  67.0     62469.0
# 4      W      2      1       Brentford  2.1  1.0  54.0     52148.0
#
#            Captain Formation Opp Formation         Referee  Match Report  \
# 0       Rúben Dias     4-3-3       4-2-3-1  Jarred Gillett  Match Report
# 1  Kevin De Bruyne   3-2-4-1       4-2-3-1  Anthony Taylor  Match Report
# 2  Kevin De Bruyne   3-2-4-1         5-4-1  Samuel Allison  Match Report
# 3  Kevin De Bruyne   3-2-4-1       4-2-3-1  Michael Oliver  Match Report
# 4      Kyle Walker   4-2-3-1         5-3-2     Darren Bond  Match Report
#
#                                                Notes  Sh  SoT  SoT%  G/Sh  \
# 0  Manchester City won on penalty kicks following...   9    1  11.1  0.11
# 1                                                NaN  11    5  45.5  0.18
# 2                                                NaN  13    4  30.8  0.23
# 3                                                NaN  23    8  34.8  0.13
# 4                                                NaN  18    7  38.9  0.11
#
#    G/SoT  Dist   FK  PK  PKatt  npxG  npxG/Sh  G-xG  np:G-xG
# 0   1.00   NaN  NaN   0      0   NaN      NaN   NaN      NaN
# 1   0.40  19.1  0.0   0      0   0.8     0.07   1.2      1.2
# 2   0.75  17.8  1.0   1      1   2.6     0.20   0.7      0.4
# 3   0.38  15.0  1.0   0      0   3.0     0.13   0.0      0.0
# 4   0.29  17.2  0.0   0      0   2.1     0.12  -0.1     -0.1

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

years = list(range(2024, 2019, -1))
all_matches = []

for year in years:
    main_logger.info(f"--- Season {year} ---")
    standings_html = scraper.fetch_html_content(standings_url)

    # Update standings_url with the previous season's link
    soup = BeautifulSoup(standings_html, 'html.parser')
    previous_season = soup.find("a", attrs={"class": "button2 prev"}).get("href")
    standings_url = f"https://fbref.com{previous_season}"

    # Find team URLs for the season
    team_urls = scraper.get_team_urls(standings_html)

    # Extract stats from each team
    for team_url in team_urls:
        # Save the team name from the URL
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        main_logger.info(f"-- {team_name} --")

        # Get match stats of the team
        team_html = scraper.fetch_html_content(team_url)
        match_data = scraper.extract_table_from_html(team_html, "Scores & Fixtures")

        # Get shooting stats of the team
        shooting_data = scraper.get_shooting_data(team_html)
        shooting_data.columns = shooting_data.columns.droplevel()

        # For some teams there aren't shooting stats
        if shooting_data.empty:
            main_logger.warning(f"{team_name} doesn't have shooting data in {year} season")
            continue

        try:
            # Merge match data with shooting data
            team_data = match_data.merge(shooting_data[['Date', 'Sh', 'SoT', 'SoT%', 'G/Sh', 'G/SoT', 'Dist', 'FK', 'PK',
                                                         'PKatt', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG']], on='Date')
        except Exception as e:
            # Log an error if there is an issue merging the data
            main_logger.error(f"Error combining {team_name} 'match_data' and 'shooting_data' for {year} season: {e}")
            continue
        # Add team and season information to the data
        team_data["team"] = team_name
        team_data["season"] = year
        all_matches.append(team_data)  # Append the team data to the list
        main_logger.info(f"Extracted data for {team_name} during season {year}.")
    # Save checkpoint
    checkpoint_df = pd.concat(all_matches)
    checkpoint_df.to_csv(f"checkpoint_season{year}.csv", index=False)

match_df = pd.concat(all_matches)

match_df.to_csv(f"Matches_{max(years)}-{min(years)}.csv", index=False)
# Out:
# [INFO] (__main__) : --- Season 2024 ---
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/comps/9/Premier-League-Stats. Call count: 4.
# [INFO] (__main__) : -- Manchester City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester City during season 2024.
# [INFO] (__main__) : -- Liverpool --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/Liverpool-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2024-2025/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Liverpool during season 2024.
# [INFO] (__main__) : -- Arsenal --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/Arsenal-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 43.97 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2024-2025/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Arsenal during season 2024.
# [INFO] (__main__) : -- Aston Villa --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/Aston-Villa-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2024-2025/matchlogs/all_comps/shooting/Aston-Villa-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Aston Villa during season 2024.
# [INFO] (__main__) : -- Chelsea --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2024-2025/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Chelsea during season 2024.
# [INFO] (__main__) : -- Brighton and Hove Albion --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2024-2025/matchlogs/all_comps/shooting/Brighton-and-Hove-Albion-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brighton and Hove Albion during season 2024.
# [INFO] (__main__) : -- Nottingham Forest --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/e4a775cb/2024-2025/matchlogs/all_comps/shooting/Nottingham-Forest-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Nottingham Forest during season 2024.
# [INFO] (__main__) : -- Tottenham Hotspur --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 56.21 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2024-2025/matchlogs/all_comps/shooting/Tottenham-Hotspur-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Tottenham Hotspur during season 2024.
# [INFO] (__main__) : -- Brentford --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cd051869/Brentford-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cd051869/2024-2025/matchlogs/all_comps/shooting/Brentford-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brentford during season 2024.
# [INFO] (__main__) : -- Fulham --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/fd962109/Fulham-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/fd962109/2024-2025/matchlogs/all_comps/shooting/Fulham-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Fulham during season 2024.
# [INFO] (__main__) : -- Bournemouth --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/4ba7cbea/2024-2025/matchlogs/all_comps/shooting/Bournemouth-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Bournemouth during season 2024.
# [INFO] (__main__) : -- Newcastle United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 56.06 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2024-2025/matchlogs/all_comps/shooting/Newcastle-United-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Newcastle United during season 2024.
# [INFO] (__main__) : -- West Ham United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2024-2025/matchlogs/all_comps/shooting/West-Ham-United-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for West Ham United during season 2024.
# [INFO] (__main__) : -- Manchester United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/Manchester-United-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2024-2025/matchlogs/all_comps/shooting/Manchester-United-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester United during season 2024.
# [INFO] (__main__) : -- Leicester City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/a2d435b3/2024-2025/matchlogs/all_comps/shooting/Leicester-City-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Leicester City during season 2024.
# [INFO] (__main__) : -- Everton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/Everton-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2024-2025/matchlogs/all_comps/shooting/Everton-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Everton during season 2024.
# [INFO] (__main__) : -- Crystal Palace --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 57.64 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2024-2025/matchlogs/all_comps/shooting/Crystal-Palace-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Crystal Palace during season 2024.
# [INFO] (__main__) : -- Ipswich Town --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b74092de/Ipswich-Town-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b74092de/2024-2025/matchlogs/all_comps/shooting/Ipswich-Town-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Ipswich Town during season 2024.
# [INFO] (__main__) : -- Wolverhampton Wanderers --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2024-2025/matchlogs/all_comps/shooting/Wolverhampton-Wanderers-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Wolverhampton Wanderers during season 2024.
# [INFO] (__main__) : -- Southampton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/33c895d4/Southampton-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/33c895d4/2024-2025/matchlogs/all_comps/shooting/Southampton-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Southampton during season 2024.
# [INFO] (__main__) : --- Season 2023 ---
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/comps/9/2023-2024/2023-2024-Premier-League-Stats. Call count: 9.
# [INFO] (__main__) : -- Manchester City --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 55.18 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2023-2024/Manchester-City-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2023-2024/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester City during season 2023.
# [INFO] (__main__) : -- Arsenal --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2023-2024/Arsenal-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2023-2024/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Arsenal during season 2023.
# [INFO] (__main__) : -- Liverpool --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2023-2024/Liverpool-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2023-2024/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Liverpool during season 2023.
# [INFO] (__main__) : -- Aston Villa --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2023-2024/Aston-Villa-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2023-2024/matchlogs/all_comps/shooting/Aston-Villa-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Aston Villa during season 2023.
# [INFO] (__main__) : -- Tottenham Hotspur --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2023-2024/Tottenham-Hotspur-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 54.99 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2023-2024/matchlogs/all_comps/shooting/Tottenham-Hotspur-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Tottenham Hotspur during season 2023.
# [INFO] (__main__) : -- Chelsea --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2023-2024/Chelsea-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2023-2024/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Chelsea during season 2023.
# [INFO] (__main__) : -- Newcastle United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2023-2024/Newcastle-United-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2023-2024/matchlogs/all_comps/shooting/Newcastle-United-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Newcastle United during season 2023.
# [INFO] (__main__) : -- Manchester United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2023-2024/Manchester-United-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2023-2024/matchlogs/all_comps/shooting/Manchester-United-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester United during season 2023.
# [INFO] (__main__) : -- West Ham United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2023-2024/West-Ham-United-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2023-2024/matchlogs/all_comps/shooting/West-Ham-United-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for West Ham United during season 2023.
# [INFO] (__main__) : -- Crystal Palace --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 56.41 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2023-2024/Crystal-Palace-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2023-2024/matchlogs/all_comps/shooting/Crystal-Palace-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Crystal Palace during season 2023.
# [INFO] (__main__) : -- Brighton and Hove Albion --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2023-2024/Brighton-and-Hove-Albion-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2023-2024/matchlogs/all_comps/shooting/Brighton-and-Hove-Albion-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brighton and Hove Albion during season 2023.
# [INFO] (__main__) : -- Bournemouth --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/4ba7cbea/2023-2024/Bournemouth-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/4ba7cbea/2023-2024/matchlogs/all_comps/shooting/Bournemouth-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Bournemouth during season 2023.
# [INFO] (__main__) : -- Fulham --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/fd962109/2023-2024/Fulham-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/fd962109/2023-2024/matchlogs/all_comps/shooting/Fulham-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Fulham during season 2023.
# [INFO] (__main__) : -- Wolverhampton Wanderers --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2023-2024/Wolverhampton-Wanderers-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 40.11 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2023-2024/matchlogs/all_comps/shooting/Wolverhampton-Wanderers-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Wolverhampton Wanderers during season 2023.
# [INFO] (__main__) : -- Everton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2023-2024/Everton-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2023-2024/matchlogs/all_comps/shooting/Everton-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Everton during season 2023.
# [INFO] (__main__) : -- Brentford --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cd051869/2023-2024/Brentford-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cd051869/2023-2024/matchlogs/all_comps/shooting/Brentford-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brentford during season 2023.
# [INFO] (__main__) : -- Nottingham Forest --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/e4a775cb/2023-2024/Nottingham-Forest-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/e4a775cb/2023-2024/matchlogs/all_comps/shooting/Nottingham-Forest-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Nottingham Forest during season 2023.
# [INFO] (__main__) : -- Luton Town --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/e297cd13/2023-2024/Luton-Town-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/e297cd13/2023-2024/matchlogs/all_comps/shooting/Luton-Town-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Luton Town during season 2023.
# [INFO] (__main__) : -- Burnley --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 40.22 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/943e8050/2023-2024/Burnley-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/943e8050/2023-2024/matchlogs/all_comps/shooting/Burnley-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Burnley during season 2023.
# [INFO] (__main__) : -- Sheffield United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/1df6b87e/2023-2024/Sheffield-United-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/1df6b87e/2023-2024/matchlogs/all_comps/shooting/Sheffield-United-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Sheffield United during season 2023.
# [INFO] (__main__) : --- Season 2022 ---
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats. Call count: 5.
# [INFO] (__main__) : -- Manchester City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2022-2023/Manchester-City-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2022-2023/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester City during season 2022.
# [INFO] (__main__) : -- Arsenal --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2022-2023/Arsenal-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2022-2023/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Arsenal during season 2022.
# [INFO] (__main__) : -- Manchester United --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 37.08 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2022-2023/Manchester-United-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2022-2023/matchlogs/all_comps/shooting/Manchester-United-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester United during season 2022.
# [INFO] (__main__) : -- Newcastle United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2022-2023/Newcastle-United-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2022-2023/matchlogs/all_comps/shooting/Newcastle-United-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Newcastle United during season 2022.
# [INFO] (__main__) : -- Liverpool --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2022-2023/Liverpool-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2022-2023/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Liverpool during season 2022.
# [INFO] (__main__) : -- Brighton and Hove Albion --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2022-2023/Brighton-and-Hove-Albion-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2022-2023/matchlogs/all_comps/shooting/Brighton-and-Hove-Albion-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brighton and Hove Albion during season 2022.
# [INFO] (__main__) : -- Aston Villa --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2022-2023/Aston-Villa-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 36.77 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2022-2023/matchlogs/all_comps/shooting/Aston-Villa-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Aston Villa during season 2022.
# [INFO] (__main__) : -- Tottenham Hotspur --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2022-2023/Tottenham-Hotspur-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2022-2023/matchlogs/all_comps/shooting/Tottenham-Hotspur-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Tottenham Hotspur during season 2022.
# [INFO] (__main__) : -- Brentford --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cd051869/2022-2023/Brentford-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cd051869/2022-2023/matchlogs/all_comps/shooting/Brentford-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brentford during season 2022.
# [INFO] (__main__) : -- Fulham --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/fd962109/2022-2023/Fulham-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/fd962109/2022-2023/matchlogs/all_comps/shooting/Fulham-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Fulham during season 2022.
# [INFO] (__main__) : -- Crystal Palace --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2022-2023/Crystal-Palace-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2022-2023/matchlogs/all_comps/shooting/Crystal-Palace-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Crystal Palace during season 2022.
# [INFO] (__main__) : -- Chelsea --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 40.07 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2022-2023/Chelsea-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2022-2023/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Chelsea during season 2022.
# [INFO] (__main__) : -- Wolverhampton Wanderers --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2022-2023/Wolverhampton-Wanderers-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2022-2023/matchlogs/all_comps/shooting/Wolverhampton-Wanderers-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Wolverhampton Wanderers during season 2022.
# [INFO] (__main__) : -- West Ham United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2022-2023/West-Ham-United-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2022-2023/matchlogs/all_comps/shooting/West-Ham-United-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for West Ham United during season 2022.
# [INFO] (__main__) : -- Bournemouth --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/4ba7cbea/2022-2023/Bournemouth-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/4ba7cbea/2022-2023/matchlogs/all_comps/shooting/Bournemouth-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Bournemouth during season 2022.
# [INFO] (__main__) : -- Nottingham Forest --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/e4a775cb/2022-2023/Nottingham-Forest-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 36.65 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/e4a775cb/2022-2023/matchlogs/all_comps/shooting/Nottingham-Forest-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Nottingham Forest during season 2022.
# [INFO] (__main__) : -- Everton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2022-2023/Everton-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2022-2023/matchlogs/all_comps/shooting/Everton-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Everton during season 2022.
# [INFO] (__main__) : -- Leicester City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/a2d435b3/2022-2023/Leicester-City-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/a2d435b3/2022-2023/matchlogs/all_comps/shooting/Leicester-City-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Leicester City during season 2022.
# [INFO] (__main__) : -- Leeds United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/5bfb9659/2022-2023/Leeds-United-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/5bfb9659/2022-2023/matchlogs/all_comps/shooting/Leeds-United-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Leeds United during season 2022.
# [INFO] (__main__) : -- Southampton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/33c895d4/2022-2023/Southampton-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/33c895d4/2022-2023/matchlogs/all_comps/shooting/Southampton-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Southampton during season 2022.
# [INFO] (__main__) : --- Season 2021 ---
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 42.19 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats. Call count: 1.
# [INFO] (__main__) : -- Manchester City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2021-2022/Manchester-City-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester City during season 2021.
# [INFO] (__main__) : -- Liverpool --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2021-2022/Liverpool-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2021-2022/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Liverpool during season 2021.
# [INFO] (__main__) : -- Chelsea --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2021-2022/Chelsea-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2021-2022/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Chelsea during season 2021.
# [INFO] (__main__) : -- Tottenham Hotspur --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2021-2022/Tottenham-Hotspur-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2021-2022/matchlogs/all_comps/shooting/Tottenham-Hotspur-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Tottenham Hotspur during season 2021.
# [INFO] (__main__) : -- Arsenal --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 30.45 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2021-2022/Arsenal-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Arsenal during season 2021.
# [INFO] (__main__) : -- Manchester United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2021-2022/Manchester-United-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2021-2022/matchlogs/all_comps/shooting/Manchester-United-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester United during season 2021.
# [INFO] (__main__) : -- West Ham United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2021-2022/West-Ham-United-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2021-2022/matchlogs/all_comps/shooting/West-Ham-United-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for West Ham United during season 2021.
# [INFO] (__main__) : -- Leicester City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/a2d435b3/2021-2022/Leicester-City-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/a2d435b3/2021-2022/matchlogs/all_comps/shooting/Leicester-City-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Leicester City during season 2021.
# [INFO] (__main__) : -- Brighton and Hove Albion --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2021-2022/Brighton-and-Hove-Albion-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 38.45 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2021-2022/matchlogs/all_comps/shooting/Brighton-and-Hove-Albion-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brighton and Hove Albion during season 2021.
# [INFO] (__main__) : -- Wolverhampton Wanderers --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2021-2022/Wolverhampton-Wanderers-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2021-2022/matchlogs/all_comps/shooting/Wolverhampton-Wanderers-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Wolverhampton Wanderers during season 2021.
# [INFO] (__main__) : -- Newcastle United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2021-2022/Newcastle-United-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2021-2022/matchlogs/all_comps/shooting/Newcastle-United-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Newcastle United during season 2021.
# [INFO] (__main__) : -- Crystal Palace --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2021-2022/Crystal-Palace-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2021-2022/matchlogs/all_comps/shooting/Crystal-Palace-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Crystal Palace during season 2021.
# [INFO] (__main__) : -- Brentford --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cd051869/2021-2022/Brentford-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cd051869/2021-2022/matchlogs/all_comps/shooting/Brentford-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brentford during season 2021.
# [INFO] (__main__) : -- Aston Villa --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 39.98 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2021-2022/Aston-Villa-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2021-2022/matchlogs/all_comps/shooting/Aston-Villa-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Aston Villa during season 2021.
# [INFO] (__main__) : -- Southampton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/33c895d4/2021-2022/Southampton-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/33c895d4/2021-2022/matchlogs/all_comps/shooting/Southampton-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Southampton during season 2021.
# [INFO] (__main__) : -- Everton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2021-2022/Everton-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2021-2022/matchlogs/all_comps/shooting/Everton-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Everton during season 2021.
# [INFO] (__main__) : -- Leeds United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/5bfb9659/2021-2022/Leeds-United-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/5bfb9659/2021-2022/matchlogs/all_comps/shooting/Leeds-United-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Leeds United during season 2021.
# [INFO] (__main__) : -- Burnley --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/943e8050/2021-2022/Burnley-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 40.16 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/943e8050/2021-2022/matchlogs/all_comps/shooting/Burnley-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Burnley during season 2021.
# [INFO] (__main__) : -- Watford --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/2abfe087/2021-2022/Watford-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/2abfe087/2021-2022/matchlogs/all_comps/shooting/Watford-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Watford during season 2021.
# [INFO] (__main__) : -- Norwich City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/1c781004/2021-2022/Norwich-City-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/1c781004/2021-2022/matchlogs/all_comps/shooting/Norwich-City-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Norwich City during season 2021.
# [INFO] (__main__) : --- Season 2020 ---
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/comps/9/2020-2021/2020-2021-Premier-League-Stats. Call count: 6.
# [INFO] (__main__) : -- Manchester City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2020-2021/Manchester-City-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b8fd03ef/2020-2021/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester City during season 2020.
# [INFO] (__main__) : -- Manchester United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2020-2021/Manchester-United-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 35.82 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/19538871/2020-2021/matchlogs/all_comps/shooting/Manchester-United-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Manchester United during season 2020.
# [INFO] (__main__) : -- Liverpool --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2020-2021/Liverpool-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/822bd0ba/2020-2021/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Liverpool during season 2020.
# [INFO] (__main__) : -- Chelsea --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2020-2021/Chelsea-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/cff3d9bb/2020-2021/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Chelsea during season 2020.
# [INFO] (__main__) : -- Leicester City --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/a2d435b3/2020-2021/Leicester-City-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/a2d435b3/2020-2021/matchlogs/all_comps/shooting/Leicester-City-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Leicester City during season 2020.
# [INFO] (__main__) : -- West Ham United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2020-2021/West-Ham-United-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/7c21e445/2020-2021/matchlogs/all_comps/shooting/West-Ham-United-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for West Ham United during season 2020.
# [INFO] (__main__) : -- Tottenham Hotspur --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 39.51 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2020-2021/Tottenham-Hotspur-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/361ca564/2020-2021/matchlogs/all_comps/shooting/Tottenham-Hotspur-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Tottenham Hotspur during season 2020.
# [INFO] (__main__) : -- Arsenal --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2020-2021/Arsenal-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/18bb7c10/2020-2021/matchlogs/all_comps/shooting/Arsenal-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Arsenal during season 2020.
# [INFO] (__main__) : -- Leeds United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/5bfb9659/2020-2021/Leeds-United-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/5bfb9659/2020-2021/matchlogs/all_comps/shooting/Leeds-United-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Leeds United during season 2020.
# [INFO] (__main__) : -- Everton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2020-2021/Everton-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d3fd31cc/2020-2021/matchlogs/all_comps/shooting/Everton-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Everton during season 2020.
# [INFO] (__main__) : -- Aston Villa --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2020-2021/Aston-Villa-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 36.84 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8602292d/2020-2021/matchlogs/all_comps/shooting/Aston-Villa-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Aston Villa during season 2020.
# [INFO] (__main__) : -- Newcastle United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2020-2021/Newcastle-United-Stats. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/b2b47a98/2020-2021/matchlogs/all_comps/shooting/Newcastle-United-Match-Logs-All-Competitions. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Newcastle United during season 2020.
# [INFO] (__main__) : -- Wolverhampton Wanderers --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2020-2021/Wolverhampton-Wanderers-Stats. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/8cec06e1/2020-2021/matchlogs/all_comps/shooting/Wolverhampton-Wanderers-Match-Logs-All-Competitions. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Wolverhampton Wanderers during season 2020.
# [INFO] (__main__) : -- Crystal Palace --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2020-2021/Crystal-Palace-Stats. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/47c64c55/2020-2021/matchlogs/all_comps/shooting/Crystal-Palace-Match-Logs-All-Competitions. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Crystal Palace during season 2020.
# [INFO] (__main__) : -- Southampton --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/33c895d4/2020-2021/Southampton-Stats. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/33c895d4/2020-2021/matchlogs/all_comps/shooting/Southampton-Match-Logs-All-Competitions. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Southampton during season 2020.
# [INFO] (__main__) : -- Brighton and Hove Albion --
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 39.54 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2020-2021/Brighton-and-Hove-Albion-Stats. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/d07537b9/2020-2021/matchlogs/all_comps/shooting/Brighton-and-Hove-Albion-Match-Logs-All-Competitions. Call count: 2.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Brighton and Hove Albion during season 2020.
# [INFO] (__main__) : -- Burnley --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/943e8050/2020-2021/Burnley-Stats. Call count: 3.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/943e8050/2020-2021/matchlogs/all_comps/shooting/Burnley-Match-Logs-All-Competitions. Call count: 4.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Burnley during season 2020.
# [INFO] (__main__) : -- Fulham --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/fd962109/2020-2021/Fulham-Stats. Call count: 5.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/fd962109/2020-2021/matchlogs/all_comps/shooting/Fulham-Match-Logs-All-Competitions. Call count: 6.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Fulham during season 2020.
# [INFO] (__main__) : -- West Bromwich Albion --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/60c6b05f/2020-2021/West-Bromwich-Albion-Stats. Call count: 7.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/60c6b05f/2020-2021/matchlogs/all_comps/shooting/West-Bromwich-Albion-Match-Logs-All-Competitions. Call count: 8.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for West Bromwich Albion during season 2020.
# [INFO] (__main__) : -- Sheffield United --
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/1df6b87e/2020-2021/Sheffield-United-Stats. Call count: 9.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Scores & Fixtures'.
# [WARNING] (Scrape.fetch_html_content) : Maximum call limit reached. Waiting for 37.77 seconds.
# [INFO] (Scrape.fetch_html_content) : Fetching HTML content from https://fbref.com/en/squads/1df6b87e/2020-2021/matchlogs/all_comps/shooting/Sheffield-United-Match-Logs-All-Competitions. Call count: 1.
# [INFO] (Scrape.extract_table_from_html) : Found table 'Shooting'.
# [INFO] (__main__) : Extracted data for Sheffield United during season 2020.
